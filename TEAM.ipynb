# %% [markdown]
# ### 1. PREPARATION
# ---
# <br> DESCRIPTION
# > <br>
# > Loading necessary libraries                       <br><br>
# > Initializing file paths                           <br><br>
# > Initializing dataframes for each file path        <br><br>
# > Storing all dataframes under a list (dfs)         <br><br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cpi     = './team/data/CPI.csv'                          # Consumer price index                  # check
eci     = './team/data/ECI.csv'                          # Employment cost index                 # check
csi     = './team/data/CONSUMER-SENTIMENT-INDEX.csv'     # Consumer sentiment index              # check
gpd     = './team/data/GPD-PRICE-DEFLATOR.csv'           # Price deflator                        # check

ipd     = './team/data/IMPORT-PRICE-INDEX.csv'           # Import price index                    # check
op      = './team/data/OIL-PRICE.csv'                    # WPI oil prices                        # check
pce     = './team/data/PCE.csv'                          # Personal consumption expenditures     # check
ppi     = './team/data/PPI.csv'                          # Producer price index                  # check

wg      = './team/data/WAGE-GROWTH.csv'                  # Wage growth                           # check
unrate  = './team/data/UNRATE.csv'                       # Unemploment rate                      # check


df_cpi      =   pd.read_csv(cpi     , index_col='DATE', parse_dates=True)
df_eci      =   pd.read_csv(eci     , index_col='DATE', parse_dates=True)
df_csi      =   pd.read_csv(csi                                         )
df_gpd      =   pd.read_csv(ipd     , index_col='DATE', parse_dates=True)
df_op       =   pd.read_csv(op      , index_col='DATE', parse_dates=True)
df_pce      =   pd.read_csv(pce     , index_col='DATE', parse_dates=True)
df_ppi      =   pd.read_csv(ppi     , index_col='DATE', parse_dates=True)
df_wg       =   pd.read_csv(wg      , index_col='DATE', parse_dates=True)
df_unemply  =   pd.read_csv(unrate  , index_col='DATE', parse_dates=True)


dfs = [
    df_cpi,
    df_eci,
    df_csi,
    df_gpd,
    df_op,
    df_pce,
    df_ppi,
    df_wg,
    df_unemply,
]



# ---------------------------------------------------------------------------------------------------
#                                             UTILITY
# ---------------------------------------------------------------------------------------------------
def check_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[col] > Q3 + 1.5 * IQR) | (df[col] < Q1 - 1.5 * (IQR))]

# %% [markdown]
# $$
# IQR = Q_3 - Q_1
# $$

# %% [markdown]
# ### 2. DATA EXPLORATION

# %%
for df in dfs:
    for column in df.columns:
        df[column].replace('.', np.nan, inplace=True)

        
for df in dfs:
    for column in df.columns:
        print(column.upper())
        print(df[column].isnull().sum())
        print('*' * 130)
        print()


df_gpd.dropna(inplace=True)
df_wg.dropna(inplace=True)
df_csi.drop('Table 1: The Index of Consumer Sentiment', axis = 1, inplace=True)
df_csi.reset_index(inplace=True)
df_csi.dropna(inplace=True)


# Combine the columns into a single datetime column
df_csi['Date'] = pd.to_datetime(df_csi['level_1'] + '-' + df_csi['level_0'] + '-01', errors='coerce')
df_csi.dropna(inplace=True)
df_csi.drop(['level_0', 'level_1'], axis = 1, inplace=True)
df_csi.columns = ['csi', 'DATE']
df_csi = df_csi[['DATE', 'csi']]



df_csi.set_index(df_csi['DATE'], inplace=True)
df = df_eci.join(df_gpd).join(df_op).join(df_pce).join(df_ppi).join(df_unemply).join(df_wg).join(df_csi).join(df_cpi)
df.drop('DATE', axis=1, inplace=True)
df.columns = ['eci', 'price_deflator', 'oil_price', 'pce', 'ppi', 'unemployment_rate', 'wage_growth', 'csi', 'cpi']
# Out:
# CPIAUCSL
# 0
# **********************************************************************************************************************************
#
# CIS1020000000000I
# 0
# **********************************************************************************************************************************
#
# TABLE 1: THE INDEX OF CONSUMER SENTIMENT
# 558
# **********************************************************************************************************************************
#
# IR
# 50
# **********************************************************************************************************************************
#
# POILWTIUSDM
# 0
# **********************************************************************************************************************************
#
# PCE
# 0
# **********************************************************************************************************************************
#
# PPIACO
# 0
# **********************************************************************************************************************************
#
# FRBATLWGTUMHWG83O
# 30
# **********************************************************************************************************************************
#
# UNRATE
# 0
# **********************************************************************************************************************************
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/191113315.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].replace('.', np.nan, inplace=True)
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/191113315.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_csi['Date'] = pd.to_datetime(df_csi['level_1'] + '-' + df_csi['level_0'] + '-01', errors='coerce')

# %%
df.head()
# Out:
#              eci price_deflator  oil_price     pce    ppi  unemployment_rate  \
# DATE
# 2001-01-01  87.6          100.5  29.482174  6987.4  140.0                4.2
# 2001-04-01  88.4           97.8  27.453810  7004.2  136.4                4.4
# 2001-07-01  89.2           96.1  26.435909  7082.3  133.4                4.6
# 2001-10-01  90.0           93.7  22.210435  7212.9  130.3                5.3
# 2002-01-01  90.7           91.6  19.607391  7184.6  128.5                5.7
#
#            wage_growth   csi    cpi
# DATE
# 2001-01-01         5.3  94.7  175.6
# 2001-04-01         5.4  88.4  176.4
# 2001-07-01         5.1  92.4  177.4
# 2001-10-01         5.1  82.7  177.6
# 2002-01-01         4.8    93  177.7

# %%
df.dtypes
# Out:
# eci                  float64
# price_deflator        object
# oil_price            float64
# pce                  float64
# ppi                  float64
# unemployment_rate    float64
# wage_growth           object
# csi                   object
# cpi                  float64
# dtype: object

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = df[column].astype('float64')

for column in df.columns:
    print(column.upper())
    print(check_outliers(df, column)[column])
    print(len(check_outliers(df, column)))
    print('*' * 150)
    print()
# Out:
# ECI
# Series([], Name: eci, dtype: float64)
# 0
# ******************************************************************************************************************************************************
#
# PRICE_DEFLATOR
# Series([], Name: price_deflator, dtype: float64)
# 0
# ******************************************************************************************************************************************************
#
# OIL_PRICE
# Series([], Name: oil_price, dtype: float64)
# 0
# ******************************************************************************************************************************************************
#
# PCE
# Series([], Name: pce, dtype: float64)
# 0
# ******************************************************************************************************************************************************
#
# PPI
# DATE
# 2022-04-01    265.310
# 2022-07-01    272.274
# 2022-10-01    265.061
# 2023-01-01    260.227
# Name: ppi, dtype: float64
# 4
# ******************************************************************************************************************************************************
#
# UNEMPLOYMENT_RATE
# DATE
# 2009-10-01    10.0
# 2010-04-01     9.9
# 2020-04-01    14.8
# 2020-07-01    10.2
# Name: unemployment_rate, dtype: float64
# 4
# ******************************************************************************************************************************************************
#
# WAGE_GROWTH
# DATE
# 2010-10-01    1.3
# 2022-01-01    6.1
# 2022-04-01    6.3
# 2022-07-01    6.3
# 2022-10-01    6.3
# 2023-01-01    6.2
# Name: wage_growth, dtype: float64
# 6
# ******************************************************************************************************************************************************
#
# CSI
# Series([], Name: csi, dtype: float64)
# 0
# ******************************************************************************************************************************************************
#
# CPI
# Series([], Name: cpi, dtype: float64)
# 0
# ******************************************************************************************************************************************************

# %% [raw]
# >> UNEMPLOMENT RATE has 4 outliers; WAGE GROWTH has 6; and PPI has 4. LETS FURTHER CHECK THEM..

# %%
check_outliers(df, 'unemployment_rate')
# Out:
#               eci  price_deflator  oil_price      pce    ppi  \
# DATE
# 2009-10-01  111.2           122.3  75.823636   9976.7  175.2
# 2010-04-01  112.1           127.7  84.497727  10182.3  184.4
# 2020-04-01  139.6           118.2  16.975000  12228.3  185.5
# 2020-07-01  140.2           122.1  40.715217  14285.1  193.0
#
#             unemployment_rate  wage_growth   csi      cpi
# DATE
# 2009-10-01               10.0          2.1  70.6  216.509
# 2010-04-01                9.9          1.8  72.2  217.403
# 2020-04-01               14.8          3.4  71.8  256.126
# 2020-07-01               10.2          3.6  72.5  258.408

# %%
check_outliers(df, 'ppi')
# Out:
#               eci  price_deflator   oil_price      pce      ppi  \
# DATE
# 2022-04-01  151.7           147.5  101.985238  17310.5  265.310
# 2022-07-01  153.5           146.4  101.918095  17556.4  272.274
# 2022-10-01  155.3           142.7   87.286667  17915.1  265.061
# 2023-01-01  157.1           141.3   78.251364  18229.6  260.227
#
#             unemployment_rate  wage_growth   csi      cpi
# DATE
# 2022-04-01                3.7          6.3  65.2  288.764
# 2022-07-01                3.5          6.3  51.5  294.977
# 2022-10-01                3.6          6.3  59.9  297.863
# 2023-01-01                3.4          6.2  64.9  300.356

# %%
check_outliers(df, 'wage_growth')
# Out:
#               eci  price_deflator   oil_price      pce      ppi  \
# DATE
# 2010-10-01  113.0           127.1   81.902381  10386.4  186.600
# 2022-01-01  149.6           140.1   83.277619  16888.6  246.453
# 2022-04-01  151.7           147.5  101.985238  17310.5  265.310
# 2022-07-01  153.5           146.4  101.918095  17556.4  272.274
# 2022-10-01  155.3           142.7   87.286667  17915.1  265.061
# 2023-01-01  157.1           141.3   78.251364  18229.6  260.227
#
#             unemployment_rate  wage_growth   csi      cpi
# DATE
# 2010-10-01                9.4          1.3  67.7  219.035
# 2022-01-01                4.0          6.1  67.2  282.390
# 2022-04-01                3.7          6.3  65.2  288.764
# 2022-07-01                3.5          6.3  51.5  294.977
# 2022-10-01                3.6          6.3  59.9  297.863
# 2023-01-01                3.4          6.2  64.9  300.356

# %% [raw]
# >> THOSE OUTLIERS DOES REFLECT REAL LIFE DATA, SO I WILL NOT DROP THEM

# %%
df.columns
# Out:
# Index(['eci', 'price_deflator', 'oil_price', 'pce', 'ppi', 'unemployment_rate',
#        'wage_growth', 'csi', 'cpi'],
#       dtype='object')

# %%
for column in df.columns:
    plt.figure(figsize=(16, 8))
    sns.histplot(df[column])
    plt.plot()

# %%
from scipy.stats import skew, kurtosis

# %%
# check skewness and kurtosis
from scipy.stats import skew, kurtosis

def check_skewedness(df, col):
    print(col.upper())
    print(skew(df[col]))
    if (skew(df[col]) < 0.5) and (skew(df[col]) > -0.5):
        print('Normal distribution.')
    elif skew(df[col]) > 0.5:
        print('Right skewed detected!')
    else:
        print('Left skewed detected!')
    print('*' * 100)

def check_kurtosis(df, col):
    print(col.upper())
    print(kurtosis(df[col]))
    if kurtosis(df[col]) == 3:
        print('Normal distribution.')
    else:
        print('Possible outliers detected! XXXXXXXXXXXXXXXXX')

# %%
# check all the skewedness value and kurtosis values:
for column in df.columns:
    check_skewedness(df, column)
    print()
    check_kurtosis(df, column)
# Out:
# ECI
# 0.443139656332699
# Normal distribution.
# ****************************************************************************************************
#
# ECI
# -0.606557040782929
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# PRICE_DEFLATOR
# -0.449508578073244
# Normal distribution.
# ****************************************************************************************************
#
# PRICE_DEFLATOR
# -0.7419787434391933
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# OIL_PRICE
# 0.1584976161507253
# Normal distribution.
# ****************************************************************************************************
#
# OIL_PRICE
# -0.7081764503611807
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# PCE
# 0.6071519617828963
# Right skewed detected!
# ****************************************************************************************************
#
# PCE
# -0.3708944086933248
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# PPI
# 0.33438182626834845
# Normal distribution.
# ****************************************************************************************************
#
# PPI
# 0.012097242630736194
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# UNEMPLOYMENT_RATE
# 1.3758599378006968
# Right skewed detected!
# ****************************************************************************************************
#
# UNEMPLOYMENT_RATE
# 2.3966114395732117
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# WAGE_GROWTH
# 0.4265726172565406
# Normal distribution.
# ****************************************************************************************************
#
# WAGE_GROWTH
# 0.13624096311942324
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# CSI
# -0.39211218347775073
# Normal distribution.
# ****************************************************************************************************
#
# CSI
# -0.9316382968599131
# Possible outliers detected! XXXXXXXXXXXXXXXXX
# CPI
# 0.4368769138610951
# Normal distribution.
# ****************************************************************************************************
#
# CPI
# -0.33642612659838544
# Possible outliers detected! XXXXXXXXXXXXXXXXX

# %%
for column in df.columns:
    plt.figure(figsize=(16, 8))
    sns.boxplot(df[column])
    plt.plot()

# %% [markdown]
# ### 3. DIVIDE THE DF INTO ONE QUATERLY DATAFRAME AND ONE YEARLY DATAFRAME AND NORMALIZATION

# %%
df.head(10)
# Out:
#              eci  price_deflator  oil_price     pce    ppi  unemployment_rate  \
# DATE
# 2001-01-01  87.6           100.5  29.482174  6987.4  140.0                4.2
# 2001-04-01  88.4            97.8  27.453810  7004.2  136.4                4.4
# 2001-07-01  89.2            96.1  26.435909  7082.3  133.4                4.6
# 2001-10-01  90.0            93.7  22.210435  7212.9  130.3                5.3
# 2002-01-01  90.7            91.6  19.607391  7184.6  128.5                5.7
# 2002-04-01  91.5            94.3  26.266364  7312.5  130.8                5.9
# 2002-07-01  92.0            94.5  26.930000  7387.3  131.2                5.8
# 2002-10-01  92.4            95.5  28.853913  7435.2  133.2                5.7
# 2003-01-01  93.3            96.9  32.911739  7541.3  135.3                5.8
# 2003-04-01  93.9            96.0  28.357727  7634.5  136.8                6.0
#
#             wage_growth   csi    cpi
# DATE
# 2001-01-01          5.3  94.7  175.6
# 2001-04-01          5.4  88.4  176.4
# 2001-07-01          5.1  92.4  177.4
# 2001-10-01          5.1  82.7  177.6
# 2002-01-01          4.8  93.0  177.7
# 2002-04-01          4.1  93.0  179.3
# 2002-07-01          3.9  88.1  180.0
# 2002-10-01          3.6  80.6  181.2
# 2003-01-01          4.1  82.4  182.6
# 2003-04-01          3.4  86.0  183.2

# %%
df_yearly = df.resample('Y').mean()
# Out:
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/482615187.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_yearly = df.resample('Y').mean()

# %%
df_yearly.plot(figsize=(16, 8))
# Out:
# <Axes: xlabel='DATE'>

# %%
df_yearly[['eci', 'price_deflator', 'oil_price', 'ppi', 'unemployment_rate', 'wage_growth', 'csi', 'cpi']].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
df_yearly.corr()
# Out:
#                         eci  price_deflator  oil_price       pce       ppi  \
# eci                1.000000        0.713999   0.340671  0.996106  0.927937
# price_deflator     0.713999        1.000000   0.872990  0.707886  0.894933
# oil_price          0.340671        0.872990   1.000000  0.347576  0.642643
# pce                0.996106        0.707886   0.347576  1.000000  0.933843
# ppi                0.927937        0.894933   0.642643  0.933843  1.000000
# unemployment_rate -0.289895        0.064482   0.164537 -0.358692 -0.207319
# wage_growth        0.301075       -0.126138  -0.234086  0.350592  0.221131
# csi               -0.283826       -0.564784  -0.634973 -0.271419 -0.495669
# cpi                0.995724        0.760252   0.407858  0.994951  0.954251
#
#                    unemployment_rate  wage_growth       csi       cpi
# eci                        -0.289895     0.301075 -0.283826  0.995724
# price_deflator              0.064482    -0.126138 -0.564784  0.760252
# oil_price                   0.164537    -0.234086 -0.634973  0.407858
# pce                        -0.358692     0.350592 -0.271419  0.994951
# ppi                        -0.207319     0.221131 -0.495669  0.954251
# unemployment_rate           1.000000    -0.732246 -0.397994 -0.287584
# wage_growth                -0.732246     1.000000 -0.052495  0.291517
# csi                        -0.397994    -0.052495  1.000000 -0.327248
# cpi                        -0.287584     0.291517 -0.327248  1.000000

# %%
cpi_line = df_yearly.cpi

# %%
for column in df_yearly.columns:
    plt.figure(figsize=(16, 8))
    plt.plot(df_yearly[column], label=column.upper())
    plt.plot(cpi_line, label='CPI')
    plt.xlabel('TIME')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
for column in df_yearly.columns:
    plt.figure(figsize=(16, 8))
    sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
    plt.title(f"{column.upper()} vs. CPI", fontsize=16)
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})
# /var/folders/t_/8l_2cmsj4ys5cqvg9j6rjk100000gn/T/ipykernel_5628/53327991.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_yearly, x = df_yearly[column], y = cpi_line, legend=True, s = 100, palette={'A':'red', 'B': 'blue'})

# %%
for column in df_yearly.columns:
    plt.figure(figsize=(16, 8))
    sns.regplot(data=df_yearly, x = df_yearly[column], y = csi_line)
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[145], line 3
#       1 for column in df_yearly.columns:
#       2     plt.figure(figsize=(16, 8))
# ----> 3     sns.regplot(data=df_yearly, x = df_yearly[column], y = csi_line)
#       4     plt.tight_layout()
#       5     plt.show()
#
# NameError: name 'csi_line' is not defined

# %%
df_yearly.corr()
# Out:
#                         eci  price_deflator  oil_price       pce       ppi  \
# eci                1.000000        0.713999   0.340671  0.996106  0.927937
# price_deflator     0.713999        1.000000   0.872990  0.707886  0.894933
# oil_price          0.340671        0.872990   1.000000  0.347576  0.642643
# pce                0.996106        0.707886   0.347576  1.000000  0.933843
# ppi                0.927937        0.894933   0.642643  0.933843  1.000000
# unemployment_rate -0.289895        0.064482   0.164537 -0.358692 -0.207319
# wage_growth        0.301075       -0.126138  -0.234086  0.350592  0.221131
# csi               -0.283826       -0.564784  -0.634973 -0.271419 -0.495669
# cpi                0.995724        0.760252   0.407858  0.994951  0.954251
#
#                    unemployment_rate  wage_growth       csi       cpi
# eci                        -0.289895     0.301075 -0.283826  0.995724
# price_deflator              0.064482    -0.126138 -0.564784  0.760252
# oil_price                   0.164537    -0.234086 -0.634973  0.407858
# pce                        -0.358692     0.350592 -0.271419  0.994951
# ppi                        -0.207319     0.221131 -0.495669  0.954251
# unemployment_rate           1.000000    -0.732246 -0.397994 -0.287584
# wage_growth                -0.732246     1.000000 -0.052495  0.291517
# csi                        -0.397994    -0.052495  1.000000 -0.327248
# cpi                        -0.287584     0.291517 -0.327248  1.000000

# %%
from scipy.stats import pearsonr

# %%
def find_pearsonr(df, col1, col2):
    result = pearsonr(df[col1], df[col2])
    print(f"The correlation coef between {col1.upper()} and {col2.upper()} is {result[0]}")
    print(f"The p-value between the {col1.upper()} and {col2.upper()} is {result[1]}")
    if result[1] > 0.05:
        print('It is too big. You cannot reject the null hypothesis! Therefore, no correlation!')
    else:
        print('There is indeed correlation between the two since p-value is too small.')
    print('*' * 100)
    print()

# %%
for column in df_yearly.columns:
    find_pearsonr(df_yearly, column, 'cpi')
# Out:
# The correlation coef between ECI and CPI is 0.9957235723090099
# The p-value between the ECI and CPI is 2.9545921707149502e-24
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between PRICE_DEFLATOR and CPI is 0.7602523330888035
# The p-value between the PRICE_DEFLATOR and CPI is 1.6257759944891605e-05
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between OIL_PRICE and CPI is 0.4078577302909291
# The p-value between the OIL_PRICE and CPI is 0.04788193534430471
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between PCE and CPI is 0.9949511678152989
# The p-value between the PCE and CPI is 1.8287940633189567e-23
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between PPI and CPI is 0.954250643877497
# The p-value between the PPI and CPI is 5.121416088747659e-13
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between UNEMPLOYMENT_RATE and CPI is -0.2875839978397561
# The p-value between the UNEMPLOYMENT_RATE and CPI is 0.17299303321413384
# It is too big. You cannot reject the null hypothesis! Therefore, no correlation!
# ****************************************************************************************************
#
# The correlation coef between WAGE_GROWTH and CPI is 0.29151694314582516
# The p-value between the WAGE_GROWTH and CPI is 0.16693048024151952
# It is too big. You cannot reject the null hypothesis! Therefore, no correlation!
# ****************************************************************************************************
#
# The correlation coef between CSI and CPI is -0.3272478590328908
# The p-value between the CSI and CPI is 0.11853942955408633
# It is too big. You cannot reject the null hypothesis! Therefore, no correlation!
# ****************************************************************************************************
#
# The correlation coef between CPI and CPI is 1.0
# The p-value between the CPI and CPI is 0.0
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************

# %% [raw]
# >> From the pearsonr statistical analysis above we can see that ECI, PRICE DEFLATOR, OIL PRICE PCE AND PPI HAVE A CORRELATION WITH CPI

# %% [markdown]
# ### CAN WE PREDICT WHEN INFLATION STARTS AND ENDS?

# %% [raw]
# >> IN ECONOMIC TERM, INFLATION < 2.5% CAN BE CONSIDERED STABILITY OF PRICE, INFLATION RATE > 2.5% CAN BE CONSIDERED A PERIOD OF INFLATION

# %%
df_yearly_2020 = df_yearly[df_yearly.index.year >= 2020]

# %%
df_yearly_2020
# Out:
#                 eci  price_deflator  oil_price       pce        ppi  \
# DATE
# 2020-12-31  140.075         122.200  38.703043  14007.90  193.57500
# 2021-12-31  145.225         132.275  66.805839  15916.50  223.75375
# 2022-12-31  152.525         144.175  93.616905  17417.65  262.27450
# 2023-12-31  159.575         140.275  79.653405  18503.90  256.54050
# 2024-12-31  163.900         139.400  74.003043  19028.00  251.30600
#
#             unemployment_rate  wage_growth     csi        cpi
# DATE
# 2020-12-31              8.850        3.675  81.475  258.42225
# 2021-12-31              5.600        3.850  80.050  269.42450
# 2022-12-31              3.700        6.250  60.950  290.99850
# 2023-12-31              3.525        5.450  65.975  303.88675
# 2024-12-31              3.700        4.700  79.000  309.68500

# %% [raw]
# >> LETS CALCULATE INFLATION

# %%
df_yearly_2020['inflation'] = df_yearly_2020['cpi'].diff() / df_yearly_2020['cpi'].shift(1) * 100
# Out:
# /var/folders/44/ywyr9h1x19sc31hw5rqj971w0000gn/T/ipykernel_30259/3040286034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yearly_2020['inflation'] = df_yearly_2020['cpi'].diff() / df_yearly_2020['cpi'].shift(1) * 100

# %%
df_yearly_2020
# Out:
#                 eci  price_deflator  oil_price       pce        ppi  \
# DATE
# 2020-12-31  140.075         122.200  38.703043  14007.90  193.57500
# 2021-12-31  145.225         132.275  66.805839  15916.50  223.75375
# 2022-12-31  152.525         144.175  93.616905  17417.65  262.27450
# 2023-12-31  159.575         140.275  79.653405  18503.90  256.54050
# 2024-12-31  163.900         139.400  74.003043  19028.00  251.30600
#
#             unemployment_rate  wage_growth     csi        cpi  inflation
# DATE
# 2020-12-31              8.850        3.675  81.475  258.42225        NaN
# 2021-12-31              5.600        3.850  80.050  269.42450   4.257470
# 2022-12-31              3.700        6.250  60.950  290.99850   8.007438
# 2023-12-31              3.525        5.450  65.975  303.88675   4.428975
# 2024-12-31              3.700        4.700  79.000  309.68500   1.908030

# %%
def check_inflation(df, col):
    return df[df[col] > 2.4]

# %%
inflation_periods = check_inflation(df_yearly_2020, 'inflation')['inflation']

# %%
start_1_index = inflation_periods.index[0]
start_1 = inflation_periods[0]
# Out:
# /var/folders/44/ywyr9h1x19sc31hw5rqj971w0000gn/T/ipykernel_30259/1259683412.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   start_1 = inflation_periods[0]

# %%
start_2_index = inflation_periods.index[1]
start_2 = inflation_periods[1]
# Out:
# /var/folders/44/ywyr9h1x19sc31hw5rqj971w0000gn/T/ipykernel_30259/1057484910.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   start_2 = inflation_periods[1]

# %%
start_3_index = inflation_periods.index[2]
start_3 = inflation_periods[2]
# Out:
# /var/folders/44/ywyr9h1x19sc31hw5rqj971w0000gn/T/ipykernel_30259/3874581035.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   start_3 = inflation_periods[2]

# %%
start_3_index
# Out:
# Timestamp('2023-12-31 00:00:00')

# %%
plt.figure(figsize=(16, 8))
plt.plot(df_yearly_2020['inflation'], marker='o', linestyle='--')

plt.annotate(text='inflationary period', xy=(start_1_index, start_1), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.scatter(start_1_index, start_1, color='red', marker='o', s= 100)

plt.annotate(text='inflationary period', xy=(start_2_index, start_2), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.scatter(start_2_index, start_2, color='red', marker='o', s=100)

plt.annotate(text='inflationary period', xy=(start_3_index, start_3))
plt.scatter(start_3_index, start_3, color='red', marker='o', s=100)

plt.plot()
# Out:
# []

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 8))

sns.regplot(data=df_yearly_2020, x='eci', y='cpi', ax=ax)

plt.show()

# %%
df_yearly_2020['eci'].plot(figsize=(16, 8), label='ECI')
df_yearly_2020['cpi'].plot(label='CPI')

plt.legend()
plt.plot()
# Out:
# []

# %% [raw]
# >> SINCE WE CAN OBSERVE MORE VARIABILITY OF TREND, SEASONALITY, RESID IN QUATERLY DATA, LETS USE IT TO FORECAST INFLATION

# %%
df_quarterly = df.resample('Q').mean()
# Out:
# /var/folders/44/ywyr9h1x19sc31hw5rqj971w0000gn/T/ipykernel_30259/1540775982.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df_quarterly = df.resample('Q').mean()

# %%
df_quarterly[['price_deflator', 'oil_price', 'ppi', 'unemployment_rate', 'wage_growth', 'csi', 'cpi']].plot(figsize=(16, 8))
# Out:
# <Axes: xlabel='DATE'>

# %%
df_quarterly.corr()
# Out:
#                         eci  price_deflator  oil_price       pce       ppi  \
# eci                1.000000        0.697173   0.326078  0.992984  0.913650
# price_deflator     0.697173        1.000000   0.867337  0.693572  0.894296
# oil_price          0.326078        0.867337   1.000000  0.343119  0.646724
# pce                0.992984        0.693572   0.343119  1.000000  0.922165
# ppi                0.913650        0.894296   0.646724  0.922165  1.000000
# unemployment_rate -0.212458        0.078056   0.106086 -0.307137 -0.157136
# wage_growth        0.247082       -0.150980  -0.220385  0.301852  0.178967
# csi               -0.267248       -0.524081  -0.550574 -0.245830 -0.473221
# cpi                0.994597        0.751370   0.400988  0.991888  0.946350
#
#                    unemployment_rate  wage_growth       csi       cpi
# eci                        -0.212458     0.247082 -0.267248  0.994597
# price_deflator              0.078056    -0.150980 -0.524081  0.751370
# oil_price                   0.106086    -0.220385 -0.550574  0.400988
# pce                        -0.307137     0.301852 -0.245830  0.991888
# ppi                        -0.157136     0.178967 -0.473221  0.946350
# unemployment_rate           1.000000    -0.655798 -0.408559 -0.212670
# wage_growth                -0.655798     1.000000 -0.043396  0.237421
# csi                        -0.408559    -0.043396  1.000000 -0.313390
# cpi                        -0.212670     0.237421 -0.313390  1.000000

# %%
for column in df_quarterly.columns:
    find_pearsonr(df_quarterly, column, 'cpi')
# Out:
# The correlation coef between ECI and CPI is 0.9945972946256716
# The p-value between the ECI and CPI is 2.5162533611584176e-91
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between PRICE_DEFLATOR and CPI is 0.7513703505371258
# The p-value between the PRICE_DEFLATOR and CPI is 4.103901427421295e-18
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between OIL_PRICE and CPI is 0.4009876703529574
# The p-value between the OIL_PRICE and CPI is 6.799728722756066e-05
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between PCE and CPI is 0.9918877373925533
# The p-value between the PCE and CPI is 2.553872270279789e-83
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between PPI and CPI is 0.9463502925034288
# The p-value between the PPI and CPI is 1.992975893889931e-46
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between UNEMPLOYMENT_RATE and CPI is -0.2126702930393171
# The p-value between the UNEMPLOYMENT_RATE and CPI is 0.040691881113915265
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between WAGE_GROWTH and CPI is 0.23742108058166295
# The p-value between the WAGE_GROWTH and CPI is 0.021933967584958976
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between CSI and CPI is -0.3133897054409837
# The p-value between the CSI and CPI is 0.002222311084758743
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************
#
# The correlation coef between CPI and CPI is 1.0
# The p-value between the CPI and CPI is 0.0
# There is indeed correlation between the two since p-value is too small.
# ****************************************************************************************************

# %% [raw]
# >> FOR QUATERLY DATA ALL THE INDICATORS HAVE A CORRELATION WITH CPI!

# %%
for column in df_quarterly.columns:
    plt.figure(figsize=(16, 8))
    plt.title(f"{column.upper()} vs. CPI", fontsize=24)
    sns.regplot(data=df_quarterly, x = df_quarterly[column], y = df_quarterly['cpi'])
    plt.tight_layout()
    plt.show()

# %%
df_quarterly['inflation'] = df_quarterly['cpi'].diff() / df_quarterly['cpi'].shift(1) * 100

# %%
df_quarterly_2020 = df_quarterly[df_quarterly.index.year >= 2020]

# %%
check_inflation(df_quarterly_2020, 'inflation')
# Out:
# Empty DataFrame
# Columns: [eci, price_deflator, oil_price, pce, ppi, unemployment_rate, wage_growth, csi, cpi, inflation]
# Index: []

# %% [raw]
# >> NO INFLATION WHICH IS GREAT!

# %%
df_quarterly_2020.iloc[:, [1,2,4,5,6,7,8,9]].plot(figsize=(16, 8))
# Out:
# <Axes: xlabel='DATE'>

# %%
df_quarterly_2020.inflation
# Out:
# DATE
# 2020-03-31    0.680912
# 2020-06-30   -1.073749
# 2020-09-30    0.890968
# 2020-12-31    0.712439
# 2021-03-31    0.871857
# 2021-06-30    1.612842
# 2021-09-30    1.965121
# 2021-12-31    1.632389
# 2022-03-31    2.154583
# 2022-06-30    2.257162
# 2022-09-30    2.151584
# 2022-12-31    0.978381
# 2023-03-31    0.836962
# 2023-06-30    0.890943
# 2023-09-30    0.526677
# 2023-12-31    0.952966
# 2024-03-31    0.700417
# Freq: QE-DEC, Name: inflation, dtype: float64

# %% [raw]
# >> ONE OF THE MOST WELL-KNOWN THOERY IN ECONOMIC IS THE 'PHILIP CURVE'. LETS EXPLORE IT:

# %%
plt.figure(figsize=(16, 8))
sns.regplot(y=df_quarterly_2020['inflation'], x=df_quarterly_2020['unemployment_rate'])
plt.title(f"UNEMPLOYMENT VS. INFLATION RATE", fontsize=24)
plt.ylabel('INFLATION')
plt.xlabel('UNEMPLOYMENT')
plt.tight_layout()
plt.show()

# %%
df_quarterly_2020.unemployment_rate.plot(figsize=(16, 8))
# Out:
# <Axes: xlabel='DATE'>

# %%
df_quarterly_2020['inflation'].rolling(window=3).mean()
# Out:
# DATE
# 2020-03-31         NaN
# 2020-06-30         NaN
# 2020-09-30    0.166044
# 2020-12-31    0.176553
# 2021-03-31    0.825088
# 2021-06-30    1.065713
# 2021-09-30    1.483273
# 2021-12-31    1.736784
# 2022-03-31    1.917364
# 2022-06-30    2.014711
# 2022-09-30    2.187776
# 2022-12-31    1.795709
# 2023-03-31    1.322309
# 2023-06-30    0.902095
# 2023-09-30    0.751527
# 2023-12-31    0.790195
# 2024-03-31    0.726687
# Freq: QE-DEC, Name: inflation, dtype: float64

# %%
df_quarterly_2020
# Out:
#               eci  price_deflator   oil_price      pce      ppi  \
# DATE
# 2020-03-31  139.1           125.2   57.716957  14815.7  199.300
# 2020-06-30  139.6           118.2   16.975000  12228.3  185.500
# 2020-09-30  140.2           122.1   40.715217  14285.1  193.000
# 2020-12-31  141.4           123.3   39.405000  14702.5  196.500
# 2021-03-31  142.9           126.5   51.849524  15047.3  204.800
# 2021-06-30  144.1           131.1   61.417727  15854.1  217.900
# 2021-09-30  146.1           134.6   72.591818  16150.8  231.850
# 2021-12-31  147.8           136.9   81.364286  16613.8  240.465
# 2022-03-31  149.6           140.1   83.277619  16888.6  246.453
# 2022-06-30  151.7           147.5  101.985238  17310.5  265.310
# 2022-09-30  153.5           146.4  101.918095  17556.4  272.274
# 2022-12-31  155.3           142.7   87.286667  17915.1  265.061
# 2023-03-31  157.1           141.3   78.251364  18229.6  260.227
# 2023-06-30  158.7           140.3   79.126500  18363.8  256.908
# 2023-09-30  160.4           139.4   75.766667  18595.4  253.835
# 2023-12-31  162.1           140.1   85.469091  18826.8  255.192
# 2024-03-31  163.9           139.4   74.003043  19028.0  251.306
#
#             unemployment_rate  wage_growth   csi      cpi  inflation
# DATE
# 2020-03-31                3.6          3.9  99.8  258.906   0.680912
# 2020-06-30               14.8          3.4  71.8  256.126  -1.073749
# 2020-09-30               10.2          3.6  72.5  258.408   0.890968
# 2020-12-31                6.8          3.8  81.8  260.249   0.712439
# 2021-03-31                6.4          3.5  79.0  262.518   0.871857
# 2021-06-30                6.1          3.1  88.3  266.752   1.612842
# 2021-09-30                5.4          4.5  81.2  271.994   1.965121
# 2021-12-31                4.5          4.3  71.7  276.434   1.632389
# 2022-03-31                4.0          6.1  67.2  282.390   2.154583
# 2022-06-30                3.7          6.3  65.2  288.764   2.257162
# 2022-09-30                3.5          6.3  51.5  294.977   2.151584
# 2022-12-31                3.6          6.3  59.9  297.863   0.978381
# 2023-03-31                3.4          6.2  64.9  300.356   0.836962
# 2023-06-30                3.4          5.1  63.7  303.032   0.890943
# 2023-09-30                3.5          5.3  71.5  304.628   0.526677
# 2023-12-31                3.8          5.2  63.8  307.531   0.952966
# 2024-03-31                3.7          4.7  79.0  309.685   0.700417

# %%
quarters = np.array([i for i in range(len(df_quarterly_2020))])
inflation_rates = df_quarterly_2020['inflation'].values

# Calculate means
mean_quarters = np.mean(quarters)
mean_inflation = np.mean(inflation_rates)

# Calculate numerator and denominator
numerator = np.sum((quarters - mean_quarters) * (inflation_rates - mean_inflation))
denominator = np.sum((quarters - mean_quarters) ** 2)

# Calculate slope (b) and intercept (a)
b = numerator / denominator
a = mean_inflation - b * mean_quarters

# Predict inflation for the next quarter
quarter_to_predict1 = len(quarters) + 1
quarter_to_predict2 = len(quarters) + 2
quarter_to_predict3 = len(quarters) + 3
predicted_inflation1 = a + b * quarter_to_predict1
predicted_inflation2 = a + b * quarter_to_predict2
predicted_inflation3 = a + b * quarter_to_predict3

print("Predicted inflation for quarter", quarter_to_predict, ":", predicted_inflation)
# Out:
# Predicted inflation for quarter 18 : 1.3967264831505743

# %%
def inflation_forecast(data, col):
    orders = np.array([i for i in range(len(data))])
    rates = data[col].values

    # calculate all means
    mean_data = np.mean(orders)
    mean_inflation = np.mean(rates)

    # calculate the numerator and denominator
    numerator = np.sum((orders - mean_data) * (rates - mean_inflation))
    denominator = np.sum((orders - mean_quarters) ** 2)

    # calculate slope b and the intercept a
    b = numerator / denominator
    a = mean_inflation - b * mean_quarters

    y_pred = a + b * (len(orders) + 1)

    return y_pred

# %%
df_quarterly_2020_inflation = df_quarterly_2020['inflation']

# %%
df_quarterly_2020['inflation']
# Out:
# DATE
# 2020-03-31    0.680912
# 2020-06-30   -1.073749
# 2020-09-30    0.890968
# 2020-12-31    0.712439
# 2021-03-31    0.871857
# 2021-06-30    1.612842
# 2021-09-30    1.965121
# 2021-12-31    1.632389
# 2022-03-31    2.154583
# 2022-06-30    2.257162
# 2022-09-30    2.151584
# 2022-12-31    0.978381
# 2023-03-31    0.836962
# 2023-06-30    0.890943
# 2023-09-30    0.526677
# 2023-12-31    0.952966
# 2024-03-31    0.700417
# Freq: QE-DEC, Name: inflation, dtype: float64

# %%
predicted_value = [predicted_inflation1, predicted_inflation2, predicted_inflation3]
date = pd.date_range(start='2024-06-30', periods=3, freq='QE')

# %%
predicted = pd.DataFrame(
    predicted_value,
    date,
)

# %%
predicted.columns = ['inflation']

# %%
df_quarterly_2020['inflation'].plot()
predicted.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 8))

sns.lineplot(data=df_quarterly_2020, x=df_quarterly_2020.index, y='inflation', ax=ax)
sns.lineplot(data=predicted, x=predicted.index, y='inflation', ax=ax)

plt.plot()
# Out:
# []

# %%
for column in df_quarterly_2020.columns:
    print(column.upper())
    print(inflation_forecast(df_quarterly_2020, column))
    print('*' * 100)
    print()
# Out:
# ECI
# 166.69362745098042
# ****************************************************************************************************
#
# PRICE_DEFLATOR
# 149.3171568627451
# ****************************************************************************************************
#
# OIL_PRICE
# 101.34898926375554
# ****************************************************************************************************
#
# PCE
# 20202.564215686274
# ****************************************************************************************************
#
# PPI
# 285.0475588235294
# ****************************************************************************************************
#
# UNEMPLOYMENT_RATE
# 1.4573529411764703
# ****************************************************************************************************
#
# WAGE_GROWTH
# 6.312254901960785
# ****************************************************************************************************
#
# CSI
# 59.61568627450981
# ****************************************************************************************************
#
# CPI
# 320.6312303921569
# ****************************************************************************************************
#
# INFLATION
# 1.3967264831505743
# ****************************************************************************************************

# %% [raw]
# >> ECI the next quater will be at 167.69
# >> PRICE DEFLATOR the next quarter will be at 149.31
# >> OIL PRICE THE NEXT QUARTER will be at 101.35
# >> PCE the next quarter will be at 20202.56
# >> PPI the next quarter will be at 285.05
# >> UNEMPLOYMENT RATE the next quarter will be 1.46
# >> WAGE GROWTH the next quarter will be at 6.31
# >> CSI the next quarter will be at 59.61
# >> CPI the next quarter will be at 320.64

# %%
df_quarterly_2020
# Out:
#               eci  price_deflator   oil_price      pce      ppi  \
# DATE
# 2020-03-31  139.1           125.2   57.716957  14815.7  199.300
# 2020-06-30  139.6           118.2   16.975000  12228.3  185.500
# 2020-09-30  140.2           122.1   40.715217  14285.1  193.000
# 2020-12-31  141.4           123.3   39.405000  14702.5  196.500
# 2021-03-31  142.9           126.5   51.849524  15047.3  204.800
# 2021-06-30  144.1           131.1   61.417727  15854.1  217.900
# 2021-09-30  146.1           134.6   72.591818  16150.8  231.850
# 2021-12-31  147.8           136.9   81.364286  16613.8  240.465
# 2022-03-31  149.6           140.1   83.277619  16888.6  246.453
# 2022-06-30  151.7           147.5  101.985238  17310.5  265.310
# 2022-09-30  153.5           146.4  101.918095  17556.4  272.274
# 2022-12-31  155.3           142.7   87.286667  17915.1  265.061
# 2023-03-31  157.1           141.3   78.251364  18229.6  260.227
# 2023-06-30  158.7           140.3   79.126500  18363.8  256.908
# 2023-09-30  160.4           139.4   75.766667  18595.4  253.835
# 2023-12-31  162.1           140.1   85.469091  18826.8  255.192
# 2024-03-31  163.9           139.4   74.003043  19028.0  251.306
#
#             unemployment_rate  wage_growth   csi      cpi  inflation
# DATE
# 2020-03-31                3.6          3.9  99.8  258.906   0.680912
# 2020-06-30               14.8          3.4  71.8  256.126  -1.073749
# 2020-09-30               10.2          3.6  72.5  258.408   0.890968
# 2020-12-31                6.8          3.8  81.8  260.249   0.712439
# 2021-03-31                6.4          3.5  79.0  262.518   0.871857
# 2021-06-30                6.1          3.1  88.3  266.752   1.612842
# 2021-09-30                5.4          4.5  81.2  271.994   1.965121
# 2021-12-31                4.5          4.3  71.7  276.434   1.632389
# 2022-03-31                4.0          6.1  67.2  282.390   2.154583
# 2022-06-30                3.7          6.3  65.2  288.764   2.257162
# 2022-09-30                3.5          6.3  51.5  294.977   2.151584
# 2022-12-31                3.6          6.3  59.9  297.863   0.978381
# 2023-03-31                3.4          6.2  64.9  300.356   0.836962
# 2023-06-30                3.4          5.1  63.7  303.032   0.890943
# 2023-09-30                3.5          5.3  71.5  304.628   0.526677
# 2023-12-31                3.8          5.2  63.8  307.531   0.952966
# 2024-03-31                3.7          4.7  79.0  309.685   0.700417

# %%
df_quarterly_2020.iloc[len(df_quarterly_2020)]
# Out:
# eci                    163.900000
# price_deflator         139.400000
# oil_price               74.003043
# pce                  19028.000000
# ppi                    251.306000
# unemployment_rate        3.700000
# wage_growth              4.700000
# csi                     79.000000
# cpi                    309.685000
# inflation                0.700417
# Name: 2024-03-31 00:00:00, dtype: float64

# %%
data_next_quarter = {
    pd.to_datetime('2024-06-30') : [167.69, 149.31, 101.35, 20202.56, 285.05, 1.46, 6.31, 59.61, 320.64]
}

new_row = pd.DataFrame(data_next_quarter).transpose()

# %%
eci_inflation = df_quarterly_2020['eci'][-1]
# Out:
# /var/folders/44/ywyr9h1x19sc31hw5rqj971w0000gn/T/ipykernel_30259/3758577207.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_quarterly_2020['eci'][-1]
# 163.9

# %%
inflation_rate_next_quarter = (eci_inflation) + (0.84 * price_deflator_inflation) + (0.74 * oil_price_inflation) + (0.95 * pce_inflation) +(0.9 * ppi_inflation) - (0.67 * unemployment_inflation) + (0.74 * wage_growth_inflation) - (0.6 * csi_inflation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[339], line 1
# ----> 1 inflation_rate_next_quarter = (eci_inflation) + (0.84 * price_deflator_inflation) + (0.74 * oil_price_inflation) + (0.95 * pce_inflation) + (0.9 * ppi_inflation) - (0.67 * unemployment_inflation) + (0.74 * wage_growth_inflation) - (0.6 * csi_inflation)
#
# NameError: name 'eci_inflation' is not defined

# %%
new_row
# Out:
#                  0       1       2         3       4     5     6      7  \
# 2024-06-30  167.69  149.31  101.35  20202.56  285.05  1.46  6.31  59.61
#
#                  8
# 2024-06-30  320.64

# %%
df_quarterly_2020
# Out:
#               eci  price_deflator   oil_price      pce      ppi  \
# DATE
# 2020-03-31  139.1           125.2   57.716957  14815.7  199.300
# 2020-06-30  139.6           118.2   16.975000  12228.3  185.500
# 2020-09-30  140.2           122.1   40.715217  14285.1  193.000
# 2020-12-31  141.4           123.3   39.405000  14702.5  196.500
# 2021-03-31  142.9           126.5   51.849524  15047.3  204.800
# 2021-06-30  144.1           131.1   61.417727  15854.1  217.900
# 2021-09-30  146.1           134.6   72.591818  16150.8  231.850
# 2021-12-31  147.8           136.9   81.364286  16613.8  240.465
# 2022-03-31  149.6           140.1   83.277619  16888.6  246.453
# 2022-06-30  151.7           147.5  101.985238  17310.5  265.310
# 2022-09-30  153.5           146.4  101.918095  17556.4  272.274
# 2022-12-31  155.3           142.7   87.286667  17915.1  265.061
# 2023-03-31  157.1           141.3   78.251364  18229.6  260.227
# 2023-06-30  158.7           140.3   79.126500  18363.8  256.908
# 2023-09-30  160.4           139.4   75.766667  18595.4  253.835
# 2023-12-31  162.1           140.1   85.469091  18826.8  255.192
# 2024-03-31  163.9           139.4   74.003043  19028.0  251.306
#
#             unemployment_rate  wage_growth   csi      cpi  inflation
# DATE
# 2020-03-31                3.6          3.9  99.8  258.906   0.680912
# 2020-06-30               14.8          3.4  71.8  256.126  -1.073749
# 2020-09-30               10.2          3.6  72.5  258.408   0.890968
# 2020-12-31                6.8          3.8  81.8  260.249   0.712439
# 2021-03-31                6.4          3.5  79.0  262.518   0.871857
# 2021-06-30                6.1          3.1  88.3  266.752   1.612842
# 2021-09-30                5.4          4.5  81.2  271.994   1.965121
# 2021-12-31                4.5          4.3  71.7  276.434   1.632389
# 2022-03-31                4.0          6.1  67.2  282.390   2.154583
# 2022-06-30                3.7          6.3  65.2  288.764   2.257162
# 2022-09-30                3.5          6.3  51.5  294.977   2.151584
# 2022-12-31                3.6          6.3  59.9  297.863   0.978381
# 2023-03-31                3.4          6.2  64.9  300.356   0.836962
# 2023-06-30                3.4          5.1  63.7  303.032   0.890943
# 2023-09-30                3.5          5.3  71.5  304.628   0.526677
# 2023-12-31                3.8          5.2  63.8  307.531   0.952966
# 2024-03-31                3.7          4.7  79.0  309.685   0.700417

# %%
new_row
# Out:
#                  0       1       2         3       4     5     6      7  \
# 2024-06-30  167.69  149.31  101.35  20202.56  285.05  1.46  6.31  59.61
#
#                  8
# 2024-06-30  320.64

# %%
(new_row.values - df_quarterly_2020.iloc[-1, [0, 1,2,3,4,5,6,7,8]].values) / df_quarterly_2020.iloc[-1, [0, 1,2,3,4,5,6,7,8]].values * 100
# Out:
# array([[  2.3123856 ,   7.10903874,  36.95382681,   6.17279798,
#          13.42745498, -60.54054054,  34.25531915, -24.5443038 ,
#           3.53746549]])

# %%
eci_inflation = 2.31
price_deflator_inflation = 7.11
oil_price_inflation = 36.95
pce_inflation = 6.17
ppi_inflation = 13.43
unemployment_inflation = -60.54
wage_growth_inflation = 32.25
csi_inflation = -24.54
cpi_inflation = 3.53

# %%
inflation_rate_next_quarter = (eci_inflation) + (0.84 * price_deflator_inflation) + (0.74 * oil_price_inflation) + (0.95 * pce_inflation) +(0.9 * ppi_inflation) - (0.67 * unemployment_inflation) + (0.74 * wage_growth_inflation) - (0.6 * csi_inflation) / 9

# %%
inflation_rate_next_quarter / 100
# Out:
# 1.196367

# %%
print(f'Inflation will be {np.round(inflation_rate_next_quarter / 100, 2)}')
# Out:
# Inflation will be 1.2
